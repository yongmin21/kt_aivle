# %% [markdown]
# ### Daum Exchange
# - `https://finance.daum.net`
# - status code : 4xx
# - setting headers

# %%
import requests
import pandas as pd

# %%
# 1. URL
URL = 'https://finance.daum.net/api/exchanges/summaries'

# %%
# 2. request(url) > response(json)
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
    'referer': 'https://finance.daum.net/exchanges'
}

response = requests.get(URL, headers=headers)
response
# Out:
# <Response [200]>

# %%
# 3. json > list, dict > DataFrame
data = response.json()['data']
df = pd.DataFrame(data)[['currencyCode', 'currencyName', 'country', 'basePrice']]
df
# Out:
#    currencyCode currencyName country  basePrice
# 0           USD           달러      미국    1331.20
# 1           JPY            엔      일본     934.61
# 2           CNY           위안      중국     188.63
# 3           EUR           유로      유로    1486.06
# 4           GBP          파운드      영국    1768.83
# 5           CHF           프랑     스위스    1572.25
# 6           CAD           달러     캐나다     981.53
# 7           NZD           달러    뉴질랜드     830.74
# 8           HKD           달러      홍콩     170.90
# 9           BRL           레알     브라질     245.38
# 10          MXN           페소     멕시코      68.92
# 11          AED          디르함  아랍에미리트     362.46
# 12          KWD          디나르    쿠웨이트    4366.35
# 13          BHD          디나르     바레인    3536.46
# 14          INR           루피      인도      15.92
# 15          SAR           리얄     사우디     354.75
# 16          NOK          크로네    노르웨이     126.79
# 17          DKK          크로나     덴마크     199.23
# 18          MYR          링키트   말레이시아     317.22
# 19          BDT           타카   방글라데시      11.14
# 20          PKR           루피    파키스탄       4.79
# 21          IDR          루피아   인도네시아       8.83
# 22          TWD           달러      대만      41.70
# 23          PHP           페소     필리핀      23.95
# 24          SEK          크로나     스웨덴     131.03
# 25          AUD           달러      호주     907.35
# 26          SGD           달러    싱가포르    1031.42
# 27          THB           바트      태국      40.21
# 28          EGP          파운드     이집트      27.43
# 29          BND           달러    브루나이    1031.42
# 30          ILS          쉐캐림    이스라엘     353.78
# 31          JOD          디나르     요르단    1877.72
# 32          VND            동     베트남       5.42
# 33          RUB           루블     러시아      14.44
# 34          HUF          포린트     헝가리       3.77
# 35          PLN          줄러티     폴란드     347.48
# 36          ZAR           랜드     남아공      76.03
# 37          MNT          투그릭      몽골       0.39
# 38          CZK          코루나      체코      59.21
# 39          KZT           텡게   카자흐스탄       2.78
# 40          QAR           리얄     카타르     365.14
# 41          TRY           리라    튀르키예      39.05
